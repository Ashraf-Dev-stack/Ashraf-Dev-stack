# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashraf-Dev-stack/Ashraf-Dev-stack/blob/main/superpower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import time

def slow_print(text, delay=0.05):
    for char in text:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(delay)
    sys.stdout.write('\n')
    sys.stdout.flush()

slow_print("Choose a superpower :)")
slow_print("1- Flying")
slow_print("2- Invisibility")
slow_print("3- Super Speed")

choice = input("Enter the number: ")

if choice == "1":
    slow_print("Now :You can fly in the sky like a superhero !!")
elif choice == "2":
    slow_print("Now :You became invisible, no one can see you !!")
elif choice == "3":
    slow_print("Now :You are as fast as lightning !!")
else:
    slow_print("Invalid choice ?")
# Out:
# Choose a superpower :)
# 1- Flying
# 2- Invisibility
# 3- Super Speed
# Enter the number: 1
# Now :You can fly in the sky like a superhero !!
